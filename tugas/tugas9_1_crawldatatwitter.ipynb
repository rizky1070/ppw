# %% [markdown]
# # Crawl Data Twitter

# %%
#@title Twitter Auth Token

twitter_auth_token = 'dd5de34a37bb4e062b1a9214f819e2a25b6ddfac'

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/keyrings/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# Install missing dependencies for chromium_headless_shell
# !sudo apt-get install -y libatk1.0-0 libatk-bridge2.0-0 libxcomposite1

# !node -v
# Out:
# ...
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.6 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,160 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,840 kB]
# ...

# %%
print("Removing existing Node.js packages...")
# !sudo apt-get purge nodejs -y

print("Removing existing NodeSource repository file...")
# !sudo rm /etc/apt/keyrings/nodesource.list || true

print("Re-installing Node.js version 20...")
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/keyrings/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# Install missing dependencies for chromium_headless_shell
# !sudo apt-get install -y libatk1.0-0 libatk-bridge2.0-0 libxcomposite1

# !node -v
# Out:
# Removing existing Node.js packages...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libc-ares2 libjs-highlight.js libnode72 nodejs-doc
# Use 'sudo apt autoremove' to remove them.
# The following packages will be REMOVED:
#   nodejs*
# 0 upgraded, 0 newly installed, 1 to remove and 62 not upgraded.
# After this operation, 929 kB disk space will be freed.
# (Reading database ... 122191 files and directories currently installed.)
# Removing nodejs (12.22.9~dfsg-1ubuntu3.6) ...
# Processing triggers for man-db (2.10.2-1) ...
# Removing existing NodeSource repository file...
# Re-installing Node.js version 20...
# ...
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# ...

# %%
print("Removing existing Node.js packages and configuration files...")
# !sudo apt-get purge nodejs -y
# !sudo rm -f /etc/apt/sources.list.d/nodesource.list /etc/apt/keyrings/nodesource.gpg || true

print("Re-installing Node.js version 20...")
# Install Node.js prerequisites
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg

# Ensure the keyrings directory exists
# !sudo mkdir -p /etc/apt/keyrings

# Download and dearmor the GPG key, ensuring a proper output file
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# Add the NodeSource repository for Node.js 20.x
# Important: ensure this file is placed in sources.list.d
# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# Update apt package index with new repository
# !sudo apt-get update

# Install Node.js
# !sudo apt-get install nodejs -y

# Install missing dependencies for chromium_headless_shell
# !sudo apt-get install -y libatk1.0-0 libatk-bridge2.0-0 libxcomposite1

# Verify Node.js version
# !node -v
# Out:
# Removing existing Node.js packages and configuration files...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libc-ares2 libjs-highlight.js libnode72 nodejs-doc
# Use 'sudo apt autoremove' to remove them.
# The following packages will be REMOVED:
#   nodejs*
# 0 upgraded, 0 newly installed, 1 to remove and 62 not upgraded.
# After this operation, 929 kB disk space will be freed.
# (Reading database ... 122191 files and directories currently installed.)
# Removing nodejs (12.22.9~dfsg-1ubuntu3.6) ...
# Processing triggers for man-db (2.10.2-1) ...
# Re-installing Node.js version 20...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://cli.github.com/packages stable InRelease
# ...

# %%
import pandas as pd

# Crawl Data

filename = 'datasettwitter.csv'
search_keyword = 'makan bergizi gratis lang:id'
limit = 5000 # Keeping the limit as it was initially, or increasing it if needed for more data.

# Adding --delay 5 to introduce a 5-second delay between requests
# !npx --yes tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" -l {limit} --token {twitter_auth_token} --delay 240
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹npm warn deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supported
# ⠹npm warn deprecated inflight@1.0.6: This module is not supported, and leaks memory. Do not use it. Check out lru-cache if you want a good and tested way to coalesce async requests by a key value, which is much more comprehensive and powerful.
# ⠸npm warn deprecated glob@7.2.3: Glob versions prior to v9 are no longer supported
# ⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"/content/tweets-data/datasettwitter.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Rename the 'name' column to 'username' if it exists
if 'name' in df.columns:
    df = df.rename(columns={'name': 'username'})

# Display the DataFrame
display(df)

# Check the length of the DataFrame
num_rows = len(df)
print(f"The number of rows in the DataFrame is: {num_rows}")
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1995511090479071574  Mon Dec 01 15:11:33 +0000 2025             375
# 1    1994979298059637172  Sun Nov 30 03:58:24 +0000 2025             141
# 2    1996128069355233362  Wed Dec 03 08:03:12 +0000 2025               2
# 3    1995032389056090135  Sun Nov 30 07:29:22 +0000 2025              28
# 4    1991813840669987265  Fri Nov 21 10:20:00 +0000 2025              16
# ..                   ...                             ...             ...
# 102  1993139012677058776  Tue Nov 25 02:05:46 +0000 2025               5
# 103  1993141443733655786  Tue Nov 25 02:15:25 +0000 2025               5
# 104  1993570666143162735  Wed Nov 26 06:41:00 +0000 2025               1
# 105  1990673073100722292  Tue Nov 18 06:47:00 +0000 2025               1
# 106  1995310349709725810  Mon Dec 01 01:53:53 +0000 2025               5
#
#                                              full_text               id_str  \
# ...

# %%
import pandas as pd

# Display general information about the DataFrame, including columns and non-null counts
df.info()

# Set display option to see all columns
pd.set_option('display.max_columns', None)

# Display the first few rows of the DataFrame to inspect data content
display(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      107 non-null    int64
#  1   created_at               107 non-null    object
#  2   favorite_count           107 non-null    int64
#  3   full_text                107 non-null    object
#  4   id_str                   107 non-null    int64
#  5   image_url                94 non-null     object
#  6   in_reply_to_screen_name  7 non-null      object
#  7   lang                     107 non-null    object
#  8   location                 0 non-null      float64
#  9   quote_count              107 non-null    int64
#  10  reply_count              107 non-null    int64
#  11  retweet_count            107 non-null    int64
#  12  tweet_url                107 non-null    object
#  13  user_id_str              107 non-null    int64
# ...
