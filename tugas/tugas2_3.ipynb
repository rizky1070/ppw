# %% [markdown]
# # Crawling Berita

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
from urllib.parse import urlparse, urljoin

def dapatkan_kategori_berita():
    """
    Fungsi untuk mengambil daftar semua kategori berita dari menu navigasi
    website bangsaonline.com.
    """
    print("Mencari kategori berita di bangsaonline.com...")
    kategori_list = {}
    url_home = "https://bangsaonline.com/"
    try:
        response = requests.get(url_home, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, "html.parser")
        
        nav_menu = soup.select_one('ul#nav')
        if not nav_menu:
            print("Menu navigasi (ul#nav) tidak ditemukan.")
            return {}

        for item in nav_menu.find_all("a"):
            href = item.get("href")
            nama_kategori = item.get_text(strip=True)
            
            if href and nama_kategori:
                path_parts = urlparse(href).path.strip("/").split("/")
                
                if len(path_parts) == 2 and path_parts[0] == 'kanal':
                    url_lengkap = urljoin(url_home, href)
                    if nama_kategori not in kategori_list:
                        kategori_list[nama_kategori] = url_lengkap

        print(f"Ditemukan {len(kategori_list)} kategori berita valid.")
        
    except requests.exceptions.RequestException as e:
        print(f"Gagal mengambil daftar kategori berita: {e}")
        
    return kategori_list

def scrape_semua_berita():
    """
    Fungsi utama untuk melakukan scraping berita dari semua kategori yang ditemukan.
    """
    daftar_kategori = dapatkan_kategori_berita()

    if not daftar_kategori:
        print("Tidak ada kategori yang bisa di-scrape. Program berhenti.")
        return

    data_berita = []
    scraped_links = set()
    url_home = "https://bangsaonline.com/"

    for nama_kategori, url_kategori in daftar_kategori.items():
        print(f"\n--- Scraping Kategori: {nama_kategori.upper()} ---")
        artikel_diambil = 0
        
        try:
            response_kategori = requests.get(url_kategori, timeout=10)
            response_kategori.raise_for_status()
            soup_kategori = BeautifulSoup(response_kategori.text, "html.parser")

            # --- SELECTOR DIKEMBALIKAN SESUAI PERMINTAAN ---
            list_artikel = soup_kategori.select("h3.entry-title a")
            
            if not list_artikel:
                print("Tidak ada tautan artikel ditemukan di halaman ini.")
                continue

            for artikel in list_artikel:
                # Anda bisa mengubah angka 2 ini jika ingin scrape lebih banyak per kategori
                if artikel_diambil >= 2:
                    break
                
                link_parsial = artikel.get("href")
                if not link_parsial:
                    continue
                
                link = urljoin(url_home, link_parsial)
                
                if link in scraped_links:
                    continue

                scraped_links.add(link)

                try:
                    resp_detail = requests.get(link, timeout=10)
                    resp_detail.raise_for_status()
                    soup_detail = BeautifulSoup(resp_detail.text, "html.parser")

                    # --- SELECTOR DIKEMBALIKAN SESUAI PERMINTAAN ---
                    judul_element = soup_detail.select_one("h1.entry-title")
                    konten_berita = soup_detail.select_one("div.post")
                    
                    if judul_element and konten_berita:
                        judul = judul_element.get_text(strip=True)
                        
                        id_berita = None
                        try:
                            path_parts = urlparse(link).path.strip("/").split("/")
                            if len(path_parts) > 1 and path_parts[1].isdigit():
                                id_berita = path_parts[1]
                        except (IndexError, AttributeError):
                            id_berita = None
                        
                        for unwanted in konten_berita.select("div.baca-juga"):
                            unwanted.decompose()
                        
                        paragraf = [p.get_text(strip=True) for p in konten_berita.select("p")]
                        isi = " ".join(paragraf)

                        if isi:
                            data_berita.append({
                                "id_berita": id_berita,
                                "kategori": nama_kategori,
                                "judul": judul,
                                "isi_berita": isi,
                                "link": link
                            })
                            artikel_diambil += 1
                            print(f"({artikel_diambil}/2) Berhasil scrape: {judul[:60]}...")
                    
                    time.sleep(1)

                except requests.exceptions.RequestException as e:
                    print(f"  -> Gagal mengambil detail dari {link}: {e}")

        except requests.exceptions.RequestException as e:
            print(f"Gagal memproses halaman kategori {url_kategori}: {e}")
            
    if not data_berita:
        print("\nTidak ada berita yang berhasil di-scrape.")
        return

    df = pd.DataFrame(data_berita)
    df = df[["id_berita", "kategori", "judul", "isi_berita", "link"]]
    
    df.to_csv("hasil_scraping_berita_bangsaonline.csv", index=False, encoding="utf-8-sig")
    print(f"\n✅ Proses scraping selesai. {len(df)} berita disimpan ke 'hasil_scraping_berita_bangsaonline.csv'")
    
    return df

# --- Untuk Menjalankan Seluruh Proses Scraping ---
if __name__ == "__main__":
    df_hasil = scrape_semua_berita()
    if df_hasil is not None:
        pd.set_option('display.max_colwidth', 100)
        print("\nContoh hasil data:")
# Out:
# Mencari kategori berita di bangsaonline.com...
# Ditemukan 37 kategori berita valid.
#
# --- Scraping Kategori: JATIM ---
# (1/2) Berhasil scrape: Judi Sabung Ayam di Pamekasan Digerebek, 6 Orang Diamankan...
# (2/2) Berhasil scrape: Pemilik Ladang Ganja di Blitar Akui Jual Ganja Kering Rp5 Ju...
#
# --- Scraping Kategori: JATIM METRO ---
# (1/2) Berhasil scrape: Permudah Warga Urus Surat Secara Digital, Pemdes Banjarsari ...
# (2/2) Berhasil scrape: Fesyar 2025 Siap Digelar di Surabaya, Gubernur Khofifah Opti...
#
# --- Scraping Kategori: JATIM TENGAH ---
# (1/2) Berhasil scrape: Wali Kota Kediri dan Staf Ahli Bidang Ekonomi Maritim Kemenk...
# (2/2) Berhasil scrape: Dukung Ketahanan Pangan Nasional, Imigrasi Kediri Tanam 200 ...
#
# --- Scraping Kategori: JATIM UTARA ---
# (1/2) Berhasil scrape: Bermekaran, Bunga Tabebuya Percantik Jalan Perkotaan di Bojo...
# (2/2) Berhasil scrape: Seleksi Sekda Bojonegoro Resmi Dibuka, ASN Berkesempatan Daf...
#
# --- Scraping Kategori: JATIM SELATAN ---
# (1/2) Berhasil scrape: Dinding Penahan Jalan Sidoutomo-Jatirejoyoso Rampung...
# (2/2) Berhasil scrape: Perkuat Sinergi Optimalisasi PAD, Pemkot Luncuran aplikasi S...
#
# --- Scraping Kategori: JATIM TIMUR ---
# (1/2) Berhasil scrape: Gandeng Ojol, Satlantas Polres Pasuruan Gelar Donor Darah di...
# (2/2) Berhasil scrape: Jangkau 22 Ribu Penerima, Pemkab Jember Salurkan Honor Guru ...
#
# --- Scraping Kategori: JATIM BARAT ---
# (1/2) Berhasil scrape: FKTP Jadi Garda Terdepan JKN, BPJS Kesehatan Dorong Edukasi ...
# (2/2) Berhasil scrape: Rencana Lanjutan Program D3 Politeknik ATK Yogyakarta di Mag...
#
# --- Scraping Kategori: JATIM MADURA ---
# (1/2) Berhasil scrape: Diwisuda Jadi Guru Ngaji, 31 WBP Lapas Pamekasan Diharapkan ...
# (2/2) Berhasil scrape: Asyik Pesta Sabu, 4 Pemuda di Pamekasan Dibekuk Unit Reskrim...
#
# --- Scraping Kategori: NASIONAL ---
# (1/2) Berhasil scrape: Khalid Basalamah Penuhi Panggilan KPK, Diperiksa  dalam Kasu...
# (2/2) Berhasil scrape: Remehkan Kritik Publik, Menkeu Purbaya Diminta Buka Telinga,...
#
# --- Scraping Kategori: NUSANTARA ---
# (1/2) Berhasil scrape: Bom Siap Meledak, Dua Pimpinan Pondok Gontor, Kiai Zarkasyi-...
# (2/2) Berhasil scrape: Rais Akbar PBNU Hadratussyaikh Ditangkap, Kiai Yusuf Hasyim ...
#
# --- Scraping Kategori: POLITIK ---
# (1/2) Berhasil scrape: Syafiuddin Ajak Pemuda Bangkalan Terapkan 4 Pilar Kebangsaan...
# (2/2) Berhasil scrape: HUT ke-24 Partai Demokrat, Dedi Irwansa Gelar Baksos Bareng ...
#
# --- Scraping Kategori: BIROKRASI ---
# (1/2) Berhasil scrape: Penerbangan Perdana dari Bandara Notohadinegoro Jember ke Ja...
# (2/2) Berhasil scrape: DPRD Kota Madiun Bahas 10 Propemperda, Fokus Lindungi Warga ...
#
# --- Scraping Kategori: RELIGIA ---
# (1/2) Berhasil scrape: Muhammadiyah pun Instruksikan Peringati Maulid Nabi, Kenapa ...
# (2/2) Berhasil scrape: Maulid Nabi Tak Ada Dalilnya? Ini Tiga Poin Penting Peringat...
#
# --- Scraping Kategori: T&J - ISLAM SEHARI-HARI ---
# (1/2) Berhasil scrape: Unik, Ulama-Ulama Besar Sunni Ternyata Berasal dari Iran, Si...
# (2/2) Berhasil scrape: Inilah Tiga Teks Suci tentang Tambang dan Penambangan, Harus...
#
# --- Scraping Kategori: TAFSIR AL QURAN AKTUAL ---
# (1/2) Berhasil scrape: Tafsir Al-Hajj 19-21: Pendeta Duluan yang Mengolok...
# (2/2) Berhasil scrape: Tafsir Al-Hajj 19-21: Duel Satu Lawan Satu Sebelum Perang Ba...
#
# --- Scraping Kategori: PESANTREN ---
# (1/2) Berhasil scrape: Ponpes Waha Bangil Gelar Doa Bersama untuk Keselamatan Bangs...
# (2/2) Berhasil scrape: Pengusulan KH M Yusuf Hasyim sebagai Pahlawan Tetap Lanjut, ...
#
# --- Scraping Kategori: ORMAS ---
# (1/2) Berhasil scrape: Ketua PC GP Ansor Bangil: Mayjen Rudy Saladin Sosok Pemimpin...
# (2/2) Berhasil scrape: PC GP Ansor Kota Probolinggo Sebut Mayjen Rudy Saladin Sosok...
#
# --- Scraping Kategori: HUKUM - KRIMINAL ---
# (1/2) Berhasil scrape: Pemilik Ladang Ganja di Blitar Akui Jual Ganja Kering Rp5 Ju...
# (2/2) Berhasil scrape: Pemilik Senapan Angin Penyerangan di Mapolres Blitar Kota Te...
#
# --- Scraping Kategori: EKONOMI ---
# (1/2) Berhasil scrape: Luncurkan Program UMKM Tumbuh Bersama di Banyuwangi, MR DIY ...
# (2/2) Berhasil scrape: Harga Cabai di Bali Alami Lonjakan, Rawit Merah Naik hingga ...
#
# --- Scraping Kategori: ENTREPRENEUR ---
# (1/2) Berhasil scrape: Ekspansi Bisnis Beras Vietnam, Gus Lilur Soroti Mafia Pupuk ...
# (2/2) Berhasil scrape: Alfamart Beri Bantuan ke Perajin Intako...
#
# --- Scraping Kategori: SPORTAINMENT ---
# (1/2) Berhasil scrape: MPL ID Season 16: RRQ Hoshi Naik, Evos Turun, Onic Tempati P...
# (2/2) Berhasil scrape: Bupati Tulungagung Apresiasi Turnamen Esport MLBB Piala Risk...
#
# --- Scraping Kategori: SELEBRITI ---
# (1/2) Berhasil scrape: Ozzy Osbourne Vokalis Black Sabbath Tutup Usia, Ini Rangkaia...
# (2/2) Berhasil scrape: Marak Rhoma Palsu, Lucu dan Menarik, Bagaimana Respons Rhoma...
#
# --- Scraping Kategori: WISATA ---
# (1/2) Berhasil scrape: Launching ATIC, Quds Royal Hotel Dukung Perkembangan Pariwis...
# (2/2) Berhasil scrape: Quds Royal Hotel Surabaya Luncurkan ATIC, Pusat Informasi Wi...
#
# --- Scraping Kategori: LIFESTYLE ---
# (1/2) Berhasil scrape: Kiai Asep Bagi-Bagi uang ke Porter Stasiun KA Pasar Turi: Re...
# (2/2) Berhasil scrape: Ramalan Zodiak Senin 21 Juli 2025: Leo Kuncinya Tenang, Gemi...
#
# --- Scraping Kategori: OLAHRAGA ---
# (1/2) Berhasil scrape: Ringkasan Turnamen Piala Asia FIBA 2025...
# (2/2) Berhasil scrape: Pecah! Tangis Haru Peserta Warnai Suksesnya Turnamen E-Sport...
#
# --- Scraping Kategori: OTOMOTIF ---
# (1/2) Berhasil scrape: Yadea Resmikan Dealer 045 di Malang, Dorong Masyarakat Beral...
# (2/2) Berhasil scrape: Mulai Adaptasi dengan Ferrari SF-25, Hamilton Optimis Hadapi...
#
# --- Scraping Kategori: PENDIDIKAN ---
# (1/2) Berhasil scrape: YMI Bersama IKA ITS Hadirkan Sepuluh Sumur Wakaf di Berbagai...
# (2/2) Berhasil scrape: Disdikbud Kota Mojokerto Gelar Bimtek Guru SD untuk Program ...
#
# --- Scraping Kategori: KESEHATAN ---
# (1/2) Berhasil scrape: ORI Campak Rubela di Sumenep Capai 55,3 Persen, Giligenting ...
# (2/2) Berhasil scrape: Warga di Madiun ini Bayar Iuran JKN Tepat Waktu demi Perlind...
#
# --- Scraping Kategori: TREN ---
# (1/2) Berhasil scrape: Prakiraan Cuaca Tulungagung Hari ini Rabu, 10 September 2025...
# (2/2) Berhasil scrape: Prakiraan Cuaca Kota Kediri Hari ini Rabu, 10 September 2025...
#
# --- Scraping Kategori: KULINER ---
# (1/2) Berhasil scrape: 4 Tips Membuat Gorengan di Rumah yang Enak dan Tetap Sehat...
# (2/2) Berhasil scrape: 4 Sajian Mie Rasa Enak yang Bisa Dibuat dan Dinikmati Bersam...
#
# --- Scraping Kategori: FIGUR ---
# (1/2) Berhasil scrape: Didampingi Nyai Alif Fadhilah, Penghargaan Maha Putra Narary...
# (2/2) Berhasil scrape: Bahas Perjuangan Kiai Abbas di UINSSC, Kiai Asep Optimis Dit...
#
# --- Scraping Kategori: SEJARAH DAN BUDAYA ---
# (1/2) Berhasil scrape: SMPN 3 Tuban Sukses Tampilkan Cerita Rakyat "Padi Gaib Mbah ...
# (2/2) Berhasil scrape: Napak Tilas Pahlawan Soetoyo Jadi Agenda Tahunan Desa Kaibon...
#
# --- Scraping Kategori: DUNIA ---
# (1/2) Berhasil scrape: HUT ke-80 RI, Baznas Terjunkan Bantuan Seberat 80 Ton ke Gaz...
# (2/2) Berhasil scrape: Pembantaian 5 Jurnalis, Perangai Yahudi dan Toleransi Islam...
#
# --- Scraping Kategori: UNIK - ANEH ---
# (1/2) Berhasil scrape: Zohran Mamdani Resmi Jadi Calon Wali Kota Muslim Pertama New...
# (2/2) Berhasil scrape: Ali Khamenei Sebut Trump Musuh Tuhan, Iran Satu-Satunya Nega...
#
# --- Scraping Kategori: PERISTIWA ---
# (1/2) Berhasil scrape: Jenazah Korban Mutilasi Dipulangkan ke Lamongan, Keluarga Uc...
# (2/2) Berhasil scrape: Bupati Bangkalan Didemo, Masyarakat Tuntut Transparansi dan ...
#
# --- Scraping Kategori: TEKNOLOGI ---
# (1/2) Berhasil scrape: Kampanye Bandingkan Brandnya di India, Samsung dan Apple Lay...
# (2/2) Berhasil scrape: Xiaomi Resmi Publikasikan Hyper OS 3, ini Fitur Terbarunya...
#
# --- Scraping Kategori: KOMUNITAS DAN LINGKUNGAN ---
# (1/2) Berhasil scrape: Ahmad Latif Basya, Pelukis Imajinatif yang Ingin Ciptakan Ge...
# (2/2) Berhasil scrape: Marwah Group Sabet Peserta Terbaik di Sekoto Karnaval 2025 K...
#
# ✅ Proses scraping selesai. 74 berita disimpan ke 'hasil_scraping_berita_bangsaonline.csv'
#
# Contoh hasil data:

# %%
df_hasil.head()
# Out:
#   id_berita      kategori  \
# 0    152149         Jatim
# 1    152148         Jatim
# 2    152132   Jatim Metro
# 3    152118   Jatim Metro
# 4    152142  Jatim Tengah
#
#                                                                                                  judul  \
# 0                                           Judi Sabung Ayam di Pamekasan Digerebek, 6 Orang Diamankan
# 1                           Pemilik Ladang Ganja di Blitar Akui Jual Ganja Kering Rp5 Juta Perkilogram
# 2                  Permudah Warga Urus Surat Secara Digital, Pemdes Banjarsari Luncurkan Aplikasi PAOD
# 3  Fesyar 2025 Siap Digelar di Surabaya, Gubernur Khofifah Optimistis Jatim Jadi Pusat Ekonomi Syariah
# 4     Wali Kota Kediri dan Staf Ahli Bidang Ekonomi Maritim Kemenko Pangan Tinjau Koperasi Merah Putih
#
#                                                                                             isi_berita  \
# 0  PAMEKASAN, BANGSAONLINE.com- Satreskrim Polres Pamekasan menggerebek arena judi sabung ayam di D...
# 1  BLITAR, BANGSAONLINE.com- Pemilik ladang ganja, SA (38), warga Desa Krisik, Kecamatan Gandusari,...
# 2  SIDOARJO, BANGSAONLINE.com- Pemerintah Desa (Pemdes) Banjarsari, Kecamatan Buduran, melakukan te...
# 3  SURABAYA, BANGSAONLINE.com- Gubernur Khofifah menyatakan optimisme tinggi terhadap penyelenggara...
# 4  KOTA KEDIRI, BANGSAONLINE.com- Wali Kota Kediri, Vinanda Prameswati, bersama Staf Ahli Bidang Ek...
#
#                                                                                                   link
# 0     https://bangsaonline.com/berita/152149/judi-sabung-ayam-di-pamekasan-digerebek-6-orang-diamankan
# 1  https://bangsaonline.com/berita/152148/pemilik-ladang-ganja-di-blitar-akui-jual-ganja-kering-rp5...
# 2  https://bangsaonline.com/berita/152132/permudah-warga-urus-surat-secara-digital-pemdes-banjarsar...
# 3  https://bangsaonline.com/berita/152118/fesyar-2025-siap-digelar-di-surabaya-gubernur-khofifah-op...
# 4  https://bangsaonline.com/berita/152142/wali-kota-kediri-dan-staf-ahli-bidang-ekonomi-maritim-kem...
