# %% [markdown]
# # Pagerank PTA

# %%
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
from collections import deque  # Antrian (queue) yang efisien
import time
import sys

def build_pagerank_dataset(start_url, max_pages=50, delay=0.1):
    """
    Melakukan crawling multi-halaman untuk membangun edge list untuk PageRank.
    
    :param start_url: URL untuk memulai crawl.
    :param max_pages: Jumlah maksimum halaman yang akan di-crawl.
    :param delay: Waktu tunggu antar-request (dalam detik) agar tidak membebani server.
    :return: DataFrame pandas dengan kolom ['Halaman Sumber', 'Link Keluar (Internal)'].
    """
    
    pages_to_visit = deque([start_url])
    visited_pages = set()
    edge_list = []
    
    # ==================================================================
    # === PERBAIKAN LOGIKA TRY/EXCEPT DI SINI ===
    # ==================================================================
    try:
        # 1. Ambil hostname dulu
        hostname = urlparse(start_url).hostname
        
        # 2. Cek apakah hostname valid SEBELUM di .replace()
        if not hostname:
            raise ValueError("Hostname tidak ditemukan. Pastikan URL diawali 'https://' atau 'http://'")
        
        # 3. Baru lakukan .replace()
        base_hostname = hostname.replace('www.', '')
        
    except (ValueError, AttributeError) as e:
        # Sekarang block ini bisa menangkap 'AttributeError' (jika hostname None)
        # atau 'ValueError' yang kita buat
        print(f"Error: URL awal tidak valid -> '{start_url}'")
        print(f"Detail: {e}")
        return pd.DataFrame(columns=["Halaman Sumber", "Link Keluar (Internal)"]) 
    # ==================================================================

    print(f"Memulai crawl dari: {start_url}")
    print(f"Domain target: {base_hostname}")
    print(f"Batas halaman: {max_pages}\n")

    IGNORED_EXTENSIONS = (
        '.png', '.jpg', '.jpeg', '.gif', '.svg', '.bmp', '.tiff', '.webp',
        '.pdf', '.doc', '.docx', '.xls', '.xlsx', '.ppt', '.pptx',
        '.zip', '.rar', '.gz', '.tar', '7z',
        '.mp4', '.mkv', '.avi', '.mov', '.mp3', '.wav', '.ogg',
        '.css', '.js', '.xml', '.json', '.csv'
    )

    while pages_to_visit and len(visited_pages) < max_pages:
        current_url = pages_to_visit.popleft()
        
        if current_url in visited_pages:
            continue
        
        try:
            cleaned_url_path = urlparse(current_url).path
        except ValueError:
            print(f"  -> [SKIP] URL tidak valid: {current_url}")
            continue 

        if cleaned_url_path.lower().endswith(IGNORED_EXTENSIONS):
            print(f"  -> [SKIP] Mengabaikan file (dari ekstensi): {current_url}")
            continue
            
        visited_pages.add(current_url)
        print(f"[{len(visited_pages)}/{max_pages}] Crawling: {current_url}")
        
        try:
            time.sleep(delay)
            
            try:
                head_response = requests.head(current_url, timeout=3, allow_redirects=True)
                head_response.raise_for_status() 
                content_type = head_response.headers.get('Content-Type', '')
                
                if 'text/html' not in content_type:
                    print(f"  -> [SKIP] Mengabaikan tipe konten non-HTML: {content_type}")
                    continue
            except requests.exceptions.RequestException as head_err:
                if 'head_response' in locals() and head_response.status_code >= 400:
                     print(f"  -> Gagal (HEAD): {current_url}: {head_err}")
                     continue
                pass

            response = requests.get(current_url, timeout=5)
            response.raise_for_status()
            
            final_content_type = response.headers.get('Content-Type', '')
            if 'text/html' not in final_content_type:
                 print(f"  -> [SKIP] Mengabaikan tipe konten non-HTML (setelah GET): {final_content_type}")
                 continue
            
            soup = BeautifulSoup(response.content, 'html.parser')
            links = soup.find_all('a', href=True)
            
            for link in links:
                href = link['href']
                
                if href.startswith(('#', 'javascript:', 'mailto:', 'tel:')) or not href.strip():
                    continue
                
                absolute_url = urljoin(current_url, href)
                absolute_url = absolute_url.split('#')[0]

                try:
                    link_hostname = urlparse(absolute_url).hostname
                    if link_hostname and link_hostname.endswith(base_hostname):
                        edge_list.append([current_url, absolute_url])
                        if absolute_url not in visited_pages:
                            pages_to_visit.append(absolute_url)
                except ValueError:
                    continue

        except requests.exceptions.RequestException as e:
            print(f"  -> Gagal mengakses (GET) {current_url}: {str(e)}")
    
    print(f"\nCrawl selesai. Total {len(visited_pages)} halaman di-visit.")
    print(f"Total {len(edge_list)} link (edge) ditemukan.")
    
    if not edge_list:
        print("Tidak ada edge yang ditemukan. DataFrame akan kosong.")
        return pd.DataFrame(columns=["Halaman Sumber", "Link Keluar (Internal)"])
    
    df = pd.DataFrame(edge_list, columns=["Halaman Sumber", "Link Keluar (Internal)"])
    # df = df[df['Halaman Sumber'] != df['Link Keluar (Internal)']]
    df = df.drop_duplicates().reset_index(drop=True)
    
    print(f"Dataset akhir memiliki {len(df)} edge.")
    
    return df

# --- Bagian Utama untuk Menjalankan Kode ---
if __name__ == "__main__":
    

    # ==================================================================
    target_url = "https://pta.trunojoyo.ac.id/" # <-- Yang benar pakai 'https://'
    # ==================================================================
    
    batas_halaman = 500
    
    start_time = time.time()
    
    pagerank_df = build_pagerank_dataset(target_url, max_pages=batas_halaman, delay=0.1)
    
    end_time = time.time()
    duration = end_time - start_time
    
    if not pagerank_df.empty:
        print("\n--- Contoh Hasil Dataset (Head) ---")
        print(pagerank_df.head(10))
        
        output_filename = "pagerank500_edges_pta.csv"
        pagerank_df.to_csv(output_filename, index=False)
        print(f"\nFile berhasil disimpan ke {output_filename}")
    else:
        print("\nDataset akhir kosong, tidak ada file CSV yang disimpan.")

    print(f"\n--- Selesai ---")
    minutes = int(duration // 60)
    seconds = int(duration % 60)
    print(f"Total waktu eksekusi: {minutes} menit {seconds} detik ({duration:.2f} detik)")
# Out:
# Memulai crawl dari: https://pta.trunojoyo.ac.id/
# Domain target: pta.trunojoyo.ac.id
# Batas halaman: 500
#
# [1/500] Crawling: https://pta.trunojoyo.ac.id/
# [2/500] Crawling: https://pta.trunojoyo.ac.id/index.html
#   -> Gagal (HEAD): https://pta.trunojoyo.ac.id/index.html: 404 Client Error: Not Found for url: https://pta.trunojoyo.ac.id/index.html
# [3/500] Crawling: https://pta.trunojoyo.ac.id/c_search/
# [4/500] Crawling: https://pta.trunojoyo.ac.id/c_template/
# [5/500] Crawling: https://pta.trunojoyo.ac.id/c_contact/
# [6/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail
500] Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/3/index.html
# [451/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/080321100009
# [452/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/080321100025
# [453/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/090321100002
# [454/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/090321100019
# [455/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/090321100001
# [456/500] Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/3/1
# [457/500] Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/3/
# [458/500] Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/3/4
# [459/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/090321100023
# [460/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/090321100018
# [461/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/090321100005
# [462/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/090321100006
# [463/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/090321100015
# [464/500] Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/3/5
# [465/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/160321100038
# [466/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/160321100052
# [467/500] Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/3/109
# [468/500] Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/3/108
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100005/080311100005.pdf-0.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100016/080311100016.pdf-0.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100016/080311100016.pdf-1.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100016/080311100016.pdf-2.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100016/080311100016.pdf-3.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100016/080311100016.pdf-4.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100016/080311100016.pdf-5.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100016/080311100016.pdf-6.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100016/080311100016.pdf-7.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100016/080311100016.pdf-8.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100016/080311100016.pdf-9.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100016/080311100016.pdf-10.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100016/080311100016.pdf-11.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100016/080311100016.pdf-12.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100016/080311100016.pdf-13.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100016/080311100016.pdf-14.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100004/080311100004.pdf-0.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100004/080311100004.pdf-1.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100030/080311100030.pdf-0.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://pta.trunojoyo.ac.id/uploads/journals/080311100024/080311100024.pdf-0.jpg
# [469/500] Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/4/index.html
# [470/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/080311100028
# [471/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/080311100006
# [472/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/080311100001
# [473/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/080311100003
# [474/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/090311100009
# [475/500] Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/4/1
# [476/500] Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/4/
# [477/500] Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/4/4
# [478/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/070311100006
# [479/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/090311100002
# [480/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/090311100001
# [481/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/090311100022
# [482/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/090311100011
# [483/500] Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/4/5
# [484/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/160311100009
# [485/500] Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/4/115
# [486/500] Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/4/114
# [487/500] Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/5/index.html
# [488/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/080341100023
# [489/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/080341100029
# [490/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/080341100007
# [491/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/070341100031
# [492/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/070341100034
# [493/500] Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/5/1
# [494/500] Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/5/
# [495/500] Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/5/4
# [496/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/070341100022
# [497/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/070341100023
# [498/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/090341100028
# [499/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/070341100002
# [500/500] Crawling: https://pta.trunojoyo.ac.id/welcome/detail/080341100026
#
# Crawl selesai. Total 500 halaman di-visit.
# Total 36890 link (edge) ditemukan.
# Dataset akhir memiliki 32123 edge.
#
# --- Contoh Hasil Dataset (Head) ---
#                  Halaman Sumber  \
# 0  https://pta.trunojoyo.ac.id/
# 1  https://pta.trunojoyo.ac.id/
# 2  https://pta.trunojoyo.ac.id/
# 3  https://pta.trunojoyo.ac.id/
# 4  https://pta.trunojoyo.ac.id/
# 5  https://pta.trunojoyo.ac.id/
# 6  https://pta.trunojoyo.ac.id/
# 7  https://pta.trunojoyo.ac.id/
# 8  https://pta.trunojoyo.ac.id/
# 9  https://pta.trunojoyo.ac.id/
#
#                               Link Keluar (Internal)
# 0             https://pta.trunojoyo.ac.id/index.html
# 1                       https://pta.trunojoyo.ac.id/
# 2              https://pta.trunojoyo.ac.id/c_search/
# 3            https://pta.trunojoyo.ac.id/c_template/
# 4             https://pta.trunojoyo.ac.id/c_contact/
# 5  https://pta.trunojoyo.ac.id/welcome/detail/170...
# 6  https://pta.trunojoyo.ac.id/welcome/detail/170...
# 7  https://pta.trunojoyo.ac.id/welcome/detail/160...
# 8        https://pta.trunojoyo.ac.id/welcome/index/2
# 9        https://pta.trunojoyo.ac.id/welcome/index/3
#
# File berhasil disimpan ke pagerank500_edges_pta.csv
#
# --- Selesai ---
# Total waktu eksekusi: 23 menit 13 detik (1393.46 detik)
