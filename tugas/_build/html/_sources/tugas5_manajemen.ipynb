# %% [markdown]
# # BERTopic Manajemen

# %%
import sys
# !{sys.executable} -m pip install bertopic gensim numpy
# Out:
# Requirement already satisfied: bertopic in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (0.17.3)
# Requirement already satisfied: gensim in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (4.3.3)
# Requirement already satisfied: numpy in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# Requirement already satisfied: hdbscan>=0.8.29 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from bertopic) (0.8.40)
# Requirement already satisfied: umap-learn>=0.5.0 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from bertopic) (0.5.9.post2)
# Requirement already satisfied: pandas>=1.1.5 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from bertopic) (2.3.3)
# Requirement already satisfied: plotly>=4.7.0 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from bertopic) (6.3.1)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from bertopic) (1.7.2)
# Requirement already satisfied: sentence-transformers>=0.4.1 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from bertopic) (5.1.1)
# Requirement already satisfied: tqdm>=4.41.1 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from bertopic) (4.67.1)
# Requirement already satisfied: llvmlite>0.36.0 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from bertopic) (0.45.1)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from gensim) (7.3.1)
# Requirement already satisfied: joblib>=1.0 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from hdbscan>=0.8.29->bertopic) (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rizky\appdata\roaming\python\python312\site-packages (from pandas>=1.1.5->bertopic) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from plotly>=4.7.0->bertopic) (2.7.0)
# Requirement already satisfied: packaging in c:\users\rizky\appdata\roaming\python\python312\site-packages (from plotly>=4.7.0->bertopic) (25.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.0->bertopic) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (4.57.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (2.8.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (0.35.3)
# Requirement already satisfied: Pillow in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (4.15.0)
# Requirement already satisfied: wrapt in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from smart-open>=1.8.1->gensim) (1.17.3)
# Requirement already satisfied: colorama in c:\users\rizky\appdata\roaming\python\python312\site-packages (from tqdm>=4.41.1->bertopic) (0.4.6)
# Requirement already satisfied: numba>=0.51.2 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from umap-learn>=0.5.0->bertopic) (0.62.1)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: filelock in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.9.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.3)
# Requirement already satisfied: requests in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\rizky\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.14.0)
# Requirement already satisfied: networkx in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.5)
# Requirement already satisfied: jinja2 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (80.9.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2025.9.18)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.6.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rizky\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.10.5)
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import ast
import gensim
import numpy as np
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

# ==============================================================================
# Tahap 1 - 4 (Sama seperti sebelumnya, tidak ada perubahan)
# ==============================================================================
print("Tahap 1: Membaca dan memproses file data...")
try:
    df = pd.read_csv('hasil_preprocessing_manajemen.csv')
    print("File berhasil dimuat.")
except FileNotFoundError:
    print("File tidak ditemukan")
    
df['tokens'] = df['hasil_preprocessing'].apply(ast.literal_eval)
tokenized_docs = df['tokens'].tolist()
print(f"Data siap. Jumlah dokumen: {len(tokenized_docs)}")
print("-" * 30)

print("Tahap 2: Melatih model Word2Vec (100 dimensi)...")
w2v_model = gensim.models.Word2Vec(
    sentences=tokenized_docs, vector_size=100, window=5, min_count=2, workers=4
)
print("Model Word2Vec selesai dilatih.")
print("-" * 30)

print("Tahap 3: Membuat wrapper embedding...")
class GensimEmbedding:
    def __init__(self, model):
        self.model = model
    def embed(self, documents):
        embeddings = []
        for doc_string in documents:
            doc_tokens = doc_string.split()
            word_vectors = [self.model.wv[word] for word in doc_tokens if word in self.model.wv]
            if not word_vectors:
                embeddings.append(np.zeros(self.model.vector_size))
            else:
                embeddings.append(np.mean(word_vectors, axis=0))
        return np.array(embeddings)
custom_embedding_model = GensimEmbedding(w2v_model)
print("Wrapper embedding siap digunakan.")
print("-" * 30)

print("Tahap 4: Melatih model BERTopic...")
vectorizer_model = CountVectorizer(stop_words=["dalam", "dan", "di", "untuk", "pada", "dengan", "yang", "itu", "ini"])
docs_for_bertopic = [" ".join(tokens) for tokens in tokenized_docs]
topic_model = BERTopic(
    embedding_model=custom_embedding_model,
    vectorizer_model=vectorizer_model,
    verbose=True
)
topics, probabilities = topic_model.fit_transform(docs_for_bertopic)
print("Model BERTopic selesai dilatih!")
print("-" * 30)

# ==============================================================================
# Tahap 5: Tampilkan Hasil (Tidak ada perubahan)
# ==============================================================================
print("Tahap 5: Menampilkan hasil topik...")
topic_info = topic_model.get_topic_info() # Simpan info topik ke variabel
print("Daftar Topik yang Ditemukan:")
print(topic_info)
print("-" * 30)

# ==============================================================================
# Tahap 6: Simpan Hasil ke File CSV 💾
# ==============================================================================
print("Tahap 6: Menyimpan hasil ke file CSV...")

# --- 1. Menyimpan Informasi Umum Setiap Topik ---
# File ini berisi daftar topik, jumlah dokumen per topik, dan kata kuncinya.
topic_info.to_csv("informasi_topik_manajemen.csv", index=False)
print("File 'informasi_topik_manajemen.csv' berhasil disimpan.")

# --- 2. Menyimpan Hasil Topik untuk Setiap Dokumen ---
# Kita buat DataFrame baru yang berisi dokumen asli dan hasil topiknya.
# `topics` adalah list nomor topik untuk setiap dokumen.
# `probabilities` adalah list probabilitas untuk setiap dokumen.
hasil_df = pd.DataFrame({
    "Dokumen": docs_for_bertopic, # Anda juga bisa menggunakan kolom asli dari df awal
    "Topik_ID": topics,
    "Probabilitas": probabilities
})

# Untuk membuatnya lebih informatif, kita bisa gabungkan dengan kata kunci topiknya
# Menggabungkan (merge) dengan topic_info berdasarkan 'Topik_ID'
hasil_df = pd.merge(hasil_df, topic_info[['Topic', 'Name', 'Representation']], left_on='Topik_ID', right_on='Topic', how='left')
hasil_df = hasil_df.drop(columns=['Topic']) # Hapus kolom 'Topic' yang redundant

hasil_df.to_csv("hasil_topik_per_dokumen_manajemen.csv", index=False)
print("File 'hasil_topik_per_dokumen_manajemen.csv' berhasil disimpan.")
print("-" * 30)
print("Proses selesai!")
# Out:
# Tahap 1: Membaca dan memproses file data...
# File berhasil dimuat.
# Data siap. Jumlah dokumen: 1026
# ------------------------------
# Tahap 2: Melatih model Word2Vec (100 dimensi)...
# 2025-10-10 12:21:43,107 - BERTopic - Embedding - Transforming documents to embeddings.
# Model Word2Vec selesai dilatih.
# ------------------------------
# Tahap 3: Membuat wrapper embedding...
# Wrapper embedding siap digunakan.
# ------------------------------
# Tahap 4: Melatih model BERTopic...
# Batches:   0%|          | 0/33 [00:00<?, ?it/s]
# 2025-10-10 12:22:23,477 - BERTopic - Embedding - Completed ✓
# 2025-10-10 12:22:23,478 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-10-10 12:22:25,656 - BERTopic - Dimensionality - Completed ✓
# 2025-10-10 12:22:25,657 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-10-10 12:22:25,727 - BERTopic - Cluster - Completed ✓
# 2025-10-10 12:22:25,732 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-10-10 12:22:25,924 - BERTopic - Representation - Completed ✓
# Model BERTopic selesai dilatih!
# ------------------------------
# Tahap 5: Menampilkan hasil topik...
# Daftar Topik yang Ditemukan:
#     Topic  Count                                   Name  \
# 0      -1    306         -1_usaha_teliti_pengaruh_kerja
# 1       0    163     0_kerja_karyawan_pengaruh_variabel
# 2       1     82      1_produk_beli_putus_produktivitas
# 3       2     58     2_motivasi_kerja_karyawan_pengaruh
# 4       3     52            3_ratio_debt_equity_current
# 5       4     48     4_rasio_profitabilitas_usaha_putar
# 6       5     46               5_teliti_daya_data_layan
# 7       6     27   6_marketing_unjung_puas_relationship
# 8       7     25                     7_loan_ldr_car_roa
# 9       8     22         8_brand_merek_nokia_smartphone
# 10      9     22      9_gaya_pimpin_demokratis_karyawan
# 11     10     20           10_tbk_portofolio_optimal_pt
# 12     11     18            11_motor_honda_sepeda_merek
# 13     12     16            12_bank_tabung_cabang_kerja
# 14     13     16   13_guru_cerdas_intelektual_spiritual
# 15     14     15             14_bank_mandiri_rasio_uang
# 16     15     15         15_usaha_bersih_bangkrut_nyata
# 17     16     15  16_leverage_usaha_ukur_profitabilitas
# 18     17     13       17_corporate_csr_governance_good
# 19     18     12               18_return_on_value_saham
# 20     19     12            19_split_stock_saham_volume
# 21     20     12          20_estate_usaha_real_property
# 22     21     11   21_job_intention_turnover_insecurity
#
#                                        Representation  \
# 0   [usaha, teliti, pengaruh, kerja, variabel, kar...
# 1   [kerja, karyawan, pengaruh, variabel, positif,...
# 2   [produk, beli, putus, produktivitas, kualitas,...
# 3   [motivasi, kerja, karyawan, pengaruh, variabel...
# 4   [ratio, debt, equity, current, to, asset, on, ...
# 5   [rasio, profitabilitas, usaha, putar, bursa, e...
# 6   [teliti, daya, data, layan, mahasiswa, beli, k...
# 7   [marketing, unjung, puas, relationship, experi...
# 8   [loan, ldr, car, roa, npl, ratio, deposit, ade...
# 9   [brand, merek, nokia, smartphone, handphone, i...
# 10  [gaya, pimpin, demokratis, karyawan, kerja, po...
# 11  [tbk, portofolio, optimal, pt, saham, proporsi...
# 12  [motor, honda, sepeda, merek, yamaha, beli, pu...
# 13  [bank, tabung, cabang, kerja, karyawan, nasaba...
# 14  [guru, cerdas, intelektual, spiritual, emosion...
# 15  [bank, mandiri, rasio, uang, bumn, sehat, perb...
# 16  [usaha, bersih, bangkrut, nyata, laba, periode...
# 17  [leverage, usaha, ukur, profitabilitas, uji, m...
# 18  [corporate, csr, governance, good, usaha, soci...
# 19  [return, on, value, saham, earning, added, eco...
# 20  [split, stock, saham, volume, dagang, beda, go...
# 21  [estate, usaha, real, property, nilai, pbv, di...
# 22  [job, intention, turnover, insecurity, the, pu...
#
#                                   Representative_Docs
# 0   [teliti tuju pengaruh putar modal kerja tumbuh...
# 1   [lingkung kerja stres kerja faktor pengaruh ke...
# 2   [anik arismah pengaruh citra merek kualitas pr...
# 3   [anisyah ika aria dewi pengaruh kompensasi kem...
# 4   [nofvi damayanti pengaruh current ratio debt t...
# 5   [delfan analisis pengaruh struktur modal rasio...
# 6   [marti ekowatianalisis pengaruh kualitas layan...
# 7   [miftahul jannata ros pengaruh experiential ma...
# 8   [ismawati analisis pengaruh capital adequacy r...
# 9   [didik prioritas utama masyarakat usaha wujud ...
# 10  [zuhruf abdur rahman pengaruh gaya pimpin demo...
# 11  [putus investasi hubung untung risiko investor...
# 12  [teliti analis pengaruh kualitas produk citra ...
# 13  [teliti tuju uji pengaruh dimensi relationship...
# 14  [teliti ambil judul teliti pengaruh kompensasi...
# 15  [teliti tuju tingkat sehat bank perintah pt ba...
# 16  [aqnes dwi sakti hamidah pengaruh struktur uan...
# 17  [teliti tuju variabel financial leverage likui...
# 18  [fadjriya tri wulandari pengaruh mekanisme cor...
# 19  [juwita ayu kusuma wati analisis pengaruh econ...
# 20  [uswatun hasanah analisis beda volume dagang s...
# 21  [sofiatul icmiah pengaruh struktur aktiva prof...
# 22  [the title of this research isthe effect of em...
# ------------------------------
# Tahap 6: Menyimpan hasil ke file CSV...
# File 'informasi_topik_manajemen.csv' berhasil disimpan.
# File 'hasil_topik_per_dokumen_manajemen.csv' berhasil disimpan.
# ------------------------------
# Proses selesai!
