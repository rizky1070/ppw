# %% [markdown]
# # Crawling Link Dalam Page

# %%
import requests
from bs4 import BeautifulSoup

def crawl_website(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an error for bad status codes

        soup = BeautifulSoup(response.content, 'html.parser')

        # Ambil semua judul h1, h2, h3
        headings = soup.find_all(['h1', 'h2', 'h3'])
        for heading in headings:
            print(f"{heading.name}: {heading.get_text()}")

        # Ambil semua link
        links = soup.find_all('a', href=True)
        for link in links:
            print(f"URL: {link['href']} | Teks: {link.get_text()}")

    except requests.exceptions.RequestException as e:
        print(f"Terjadi kesalahan saat mengakses {url}: {e}")

# Gunakan fungsi
crawl_website("https://its.ac.id")
# Out:
# h3: Welcome To ITS
# h2: ITS Promotes Indonesian Startups in Dubai
# h3: Study at ITS
# h2: ITS Spektronics Team Wins Two National Championships
# h3: Research
# h2: Drainage Blockage Detection Robot Developed by ITS Students
# h1:
#             Experience more on institut teknologi sepuluh nopember
# h3: Scholarship
# h3: PPID
# h3: Admission
# h3: Selection Path
# h3: Tuition Fees
# h3: Discover Passion
# h3:
# ITS News
#
# h3:
# ITS MULTI-CAMPUS
#
# h2: SUKOLILO
# h2: MANYAR
# h2: COKROAMINOTO
# h2: BUNCITAN
# h3:
# Public Services
#
# h3:
# AGENDAS
#
# h3: 25
# h3: 05
# h3: 03
# URL: https://www.its.ac.id/ | Teks:
#
#
# URL: https://www.its.ac.id/admission/ | Teks: Prospective Students
# URL: https://www.its.ac.id/current-student/ | Teks: Current Students
# URL: https://www.its.ac.id/fresher/ | Teks: New Student
# URL: https://www.its.ac.id/lecturer-and-staff/ | Teks: Lecturers & Staffs
# URL: https://www.its.ac.id/parents/ | Teks: Parents
# URL: https://www.its.ac.id/alumni/ | Teks: Alumni
# URL: http://danaabadi.its.ac.id/web/ | Teks: Donate
# URL: https://www.youtube.com/user/itseurekatv/live | Teks: Live
# URL: # | Teks: en
# URL: https://www.its.ac.id/id/beranda/ | Teks: Bahasa Indonesia
# URL: javascript:; | Teks: English
# URL: https://my.its.ac.id/ | Teks:
#                             myITS
#
# URL: # | Teks: ITS Profile
# URL: https://www.its.ac.id/about-its/ | Teks: Brief Profile
# URL: https://www.its.ac.id/about-its/facts-and-history/ | Teks: Facts and History
# URL: https://www.its.ac.id/about-its/ranking/ | Teks: Ranking
# URL: https://www.its.ac.id/about-its/executive-board/ | Teks: Executive Board
# URL: https://www.its.ac.id/about-its/award-for-its/ | Teks: Award For ITS
# URL: https://www.its.ac.id/about-its/its-awards/ | Teks: Award From ITS
# URL: https://www.its.ac.id/about-its/vision-and-mission/ | Teks: Vision and Mission
# URL: https://www.its.ac.id/about-its/organization-structure/ | Teks: Organization Structure
# URL: https://www.its.ac.id/about-its/offices-in-its/ | Teks: Offices in ITS
# URL: http://danaabadi.its.ac.id/web/ | Teks: Endowment Fund
# URL: https://www.its.ac.id/about-its/brand-guidelines/ | Teks: Brand Guidelines
# URL: https://www.its.ac.id/about-its/visit-its/ | Teks: Visit ITS
# URL: # | Teks: Admission
# URL: https://www.its.ac.id/admission/sarjana/ | Teks: Undergraduate Program
# URL: https://www.its.ac.id/admission/pascasarjana/ | Teks: Master Program
# URL: https://www.its.ac.id/admission/sarjana-terapan/ | Teks: Applied Undergraduate Program
# URL: https://www.its.ac.id/admission/profesi/ | Teks: Professional Program
# URL: https://www.its.ac.id/admission/iup/ | Teks: IUP
# URL: https://www.its.ac.id/international/experiencing-its/prospective-student/ | Teks: International Admission
# URL: # | Teks: Study at ITS
# URL: https://www.its.ac.id/study-at-its/#field | Teks: Faculties & School
# URL: https://www.its.ac.id/campus-life/explore-its/ | Teks: Explore ITS
# URL: https://www.its.ac.id/campus-life/theres-always-something-interesting/ | Teks: Campus Life
# URL: https://www.its.ac.id/study-at-its/study-program/ | Teks: Study Program
# URL: https://www.its.ac.id/international/ | Teks: International Students
# URL: # | Teks: Research
# URL: https://www.its.ac.id/research/research-focus/ | Teks: Research Focus
# URL: https://www.its.ac.id/research/our-researcher/ | Teks: Our Researcher
# URL: https://www.its.ac.id/research/student-research/ | Teks: Student Research
# URL: https://www.its.ac.id/research/research-facilities/ | Teks: Research Facilities
# URL: https://www.its.ac.id/research/research-publications/ | Teks: Research Publications
# URL: https://www.its.ac.id/research/6613-2/ | Teks: Research Collaborations
# URL: # | Teks: Innovation
# URL: https://www.its.ac.id/industry/product-innovation/ | Teks: Product Innovation
# URL: https://www.its.ac.id/stp/ | Teks: Science Techno Park
# URL: https://www.its.ac.id/industry/facilities-and-services/ | Teks: Facilities and Services
# URL: https://www.its.ac.id/industry/workforce-development/ | Teks: Workforce Development
# URL: # | Teks: Initiatives
# URL: https://www.its.ac.id/initiatives/enhancing-diversity/ | Teks: Enhancing Diversity
# URL: https://www.its.ac.id/initiatives/business-entrepreneurship/ | Teks: Business and Entrepreneurship
# URL: https://www.its.ac.id/initiatives/smart-eco-campus/ | Teks: ITS Smart Eco-Campus
# URL: https://www.its.ac.id/initiatives/collaborative-work/ | Teks: Collaborative Works
# URL: https://www.its.ac.id/initiatives/sustainability2/ | Teks: Sustainability
# URL: # | Teks: Services
# URL: https://www.its.ac.id/public-services/academic-and-student-affairs/ | Teks: Academic and Student Affairs
# URL: https://www.its.ac.id/public-services/planning-finance-and-infrastructure/ | Teks: Planning, Finance & Infrastructure
# URL: https://www.its.ac.id/public-services/human-resources-organization-and-information-system-technology/ | Teks: Human Resources, Organization & IT
# URL: https://www.its.ac.id/public-services/research-innovation-cooperation-and-alumni/ | Teks: Research, Innovation, Cooperation & Alumni
# URL: https://www.its.ac.id/public-services/secretary-of-the-institute/ | Teks: Secretary of the Institute
# URL: https://www.its.ac.id/public-services/internal-audit/ | Teks: Internal Audit
# URL: https://www.its.ac.id/public-services/quality-control/ | Teks: Quality Control
# URL: https://www.its.ac.id/public-services/information-and-complaints/ | Teks: Information and Complaint
# URL: https://www.its.ac.id/public-services/global-partnerships/ | Teks: Global Partnerships
# URL: https://www.its.ac.id/news/en/ | Teks: News
# URL: javascript:; | Teks:
#
#
# URL: javascript:; | Teks:
#
#
# URL: https://www.its.ac.id/news/2025/09/06/geber-pameran-di-dubai-its-dorong-ekosistem-investasi-startup-indonesia/ | Teks:
#
#
# URL: https://www.its.ac.id/news/2025/09/01/bravo-spektronics-its-sabet-dua-juara-kompetisi-nasional/ | Teks:
#
#
# URL: https://www.its.ac.id/news/2025/09/03/robogo-robot-pendeteksi-sumbatan-gorong-gorong-karya-mahasiswa-its/ | Teks:
#
#
# URL: https://www.its.ac.id/admission/#beasiswa | Teks:
# URL: https://www.its.ac.id/ppid/ | Teks:
# URL: https://www.its.ac.id/admission | Teks:
# URL: https://www.its.ac.id/admission/#jalurseleksi | Teks:
# URL: https://www.its.ac.id/admission/snbp/#biaya-pendidikan | Teks:
# URL: http://www.its.ac.id/study-at-its/ | Teks:
# URL: # | Teks:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# URL: javascript:; | Teks:
#
#
# URL: javascript:; | Teks:
#
#
# URL: http://line.me/R/msg/text/?https://www.its.ac.id/news/en/its-doctors-study-landfill-mining-potential-in-integrated-waste-processing-sites/ - ITS Doctors Study Landfill Mining Potential in Integrated Waste Processing Sites | Teks:
#
#
# URL: javascript:; | Teks:
#
#
# URL: javascript:; | Teks:
#
#
# URL: https://www.its.ac.id/news/en/its-doctors-study-landfill-mining-potential-in-integrated-waste-processing-sites/ | Teks:
#                                                 ITS Doctors Study Landfill Mining Potential in Integrated Waste Processing Sites
#
# URL: https://www.its.ac.id/news/en/its-doctors-study-landfill-mining-potential-in-integrated-waste-processing-sites/ | Teks:
#                                             Read more
#
# URL: https://youtu.be/pEXGMDW7OEI | Teks:
#
#
# URL: https://youtu.be/pEXGMDW7OEI | Teks: Congratulations on Fasting Ramadan 1446 H
# URL: https://www.its.ac.id/news/en/its-indonesian-navy-supports-underwater-technology-innovation-towards-golden-indonesia-2045/ | Teks:
#
#
# URL: https://www.its.ac.id/news/en/its-indonesian-navy-supports-underwater-technology-innovation-towards-golden-indonesia-2045/ | Teks:
# 		                          ITS – Indonesian Navy Supports Underwater Technology Innovation Towards Golden Indonesia 2045
#
# URL: https://www.its.ac.id/news/en/monitoring-sea-level-rise-its-professor-develops-altimetry-satellite/ | Teks:
#
#
# URL: https://www.its.ac.id/news/en/monitoring-sea-level-rise-its-professor-develops-altimetry-satellite/ | Teks:
# 		                          Monitoring Sea Level Rise, ITS Professor Develops Altimetry Satellite
#
# URL: https://www.its.ac.id/news | Teks: More ITS News
# URL: https://www.its.ac.id/id/tentang-its/kantor-its/its-multikampus/its-sukolilo/ | Teks: SUKOLILO
# URL: https://www.its.ac.id/id/tentang-its/kantor-its/its-multikampus/its-manyar/ | Teks: MANYAR
# URL: https://www.its.ac.id/id/tentang-its/kantor-its/its-multikampus/its-cokroaminoto/ | Teks: COKROAMINOTO
# URL:  | Teks: BUNCITAN
# URL: https://www.its.ac.id/ppid/ | Teks:
# URL: https://www.its.ac.id/ppid/whistle-blowing-system/ | Teks:
# URL: https://www.lapor.go.id | Teks:
# URL: https://www.its.ac.id/ppid/laporan-keuangan/ | Teks:
# URL: https://www.kemdikbud.go.id | Teks:
# URL: https://www.its.ac.id/gpr/ | Teks:
# URL: https://www.its.ac.id/burb/id/layanan-plt/ | Teks:
# URL: https://servicedesk.its.ac.id/ | Teks:
# URL: https://www.its.ac.id/id/layanan/ | Teks: Other Services
# URL: https://www.its.ac.id/agenda/cenim-2025-the-6th-international-conference-on-computer-engineering-network-and-intelligent-multimedia/ | Teks: CENIM 2025: The 6th International Conference on Computer Engineering, Network and Intelligent Multimedia
# URL: https://www.its.ac.id/agenda/departement-of-physics-the-4th-international-symposium-on-physics-and-applications-ispa-2025/ | Teks: Departement of Physics: The 4th International Symposium on Physics and Applications (ISPA) 2025
# URL: https://www.its.ac.id/creabiz-international-week/ | Teks: Creabiz International Week (CIW) 2025
# URL: https://www.its.ac.id/agenda/ | Teks: See More Announcements and Agendas
# URL: https://www.youtube.com/user/itseurekatv | Teks:
#
#
# URL: https://www.instagram.com/its_campus/ | Teks:
#
#
# URL: https://id-id.facebook.com/InstitutTeknologiSepuluhNopember/ | Teks:
#
#
# URL: https://twitter.com/its_campus | Teks:
#
#
# URL: https://id.linkedin.com/school/its-campus/ | Teks:
#
#
# URL: https://lin.ee/fxmXOiU | Teks:
#
#
# URL: https://www.tiktok.com/@its_campus | Teks:
#
#
# URL: https://scholar.its.ac.id/ | Teks:
#
#
# URL: https://www.its.ac.id/campus-life/ | Teks: Campus Life
# URL: https://www.its.ac.id/research/ | Teks: Research
# URL: https://www.its.ac.id/industry/ | Teks: Industry
# URL: https://www.its.ac.id/initiatives/ | Teks: Initiatives
# URL: https://www.its.ac.id/about-its/ | Teks: ITS Profile
# URL: https://www.its.ac.id/en/study-at-its/#field | Teks: Field of Study
# URL: https://www.its.ac.id/study-at-its/faculties-and-departments/ | Teks: Departements
# URL: https://www.its.ac.id/en/study-at-its/#studyprogram | Teks: Study Programs
# URL: https://www.its.ac.id/en/study-at-its/#international-students | Teks: International Students
# URL: https://www.its.ac.id/campus-life/explore-its/ | Teks: Explore ITS
# URL: https://www.its.ac.id/campus-life/student-activities/ | Teks: Student Activities
# URL: https://www.its.ac.id/id/explore-surabaya/ | Teks: Explore Surabaya
# URL: https://www.its.ac.id/research/research-focus/ | Teks: Research Focus
# URL: https://www.its.ac.id/research/student-research/ | Teks: Student Research
# URL: https://www.its.ac.id/research/research-publications/ | Teks: Research Publications
# URL: https://www.its.ac.id/research/our-researcher/ | Teks: Our Researcher
# URL: https://www.its.ac.id/research/research-facilities/ | Teks: Research Facilities
# URL: https://www.its.ac.id/research/research-collaborations/ | Teks: Research Collaborations
# URL: https://www.its.ac.id/industry/science-techno-park/ | Teks: Science Techno Park
# URL: https://www.its.ac.id/industry/product-innovation/ | Teks: Innovation Products
# URL: https://www.its.ac.id/industry/workforce-development/ | Teks: Workforce Development
# URL: https://www.its.ac.id/industry/facilities-and-services/ | Teks: Facilities and Services
# URL: https://www.its.ac.id/initiatives/enhancing-diversity/ | Teks: Diversity and Inclusion
# URL: https://www.its.ac.id/initiatives/smart-eco-campus/ | Teks: ITS Smart Eco Campus
# URL: https://www.its.ac.id/initiatives/business-entrepreneurship/ | Teks: Business & Entrepreneurship
# URL: https://www.its.ac.id/initiatives/collaborative-work/ | Teks: Collaborative Works
# URL: https://www.its.ac.id/initiatives/sustainability2/ | Teks: Sustainability
# URL: https://www.its.ac.id/id/brief-profile/ | Teks: Brief Profile
# URL: https://www.its.ac.id/about-its/offices-in-its/ | Teks: Offices in ITS
# URL: https://www.its.ac.id/about-its/visit-its/ | Teks: Visit ITS
# URL: https://www.its.ac.id/about-its/its-awards/ | Teks: ITS Awards
# URL: https://www.its.ac.id/?page_id=11494 | Teks: Campus Facilities
# URL: https://www.its.ac.id/about-its/executive-board/ | Teks: Executive Board
# URL: https://www.its.ac.id/about-its/vision-and-mission/ | Teks: Vision and Mission
# URL: # | Teks:

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import pandas as pd
# Kita tidak butuh 'tabulate' lagi di Jupyter

def get_internal_links_df(url):
    """
    Fungsi ini melakukan crawling, memfilter link internal, 
    dan MENGEMBALIKAN sebuah DataFrame.
    """
    try:
        base_hostname = urlparse(url).hostname.replace('www.', '')
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        
        scraped_data = []
        links = soup.find_all('a', href=True)
        print(f"Memeriksa {len(links)} total link yang ditemukan di {url}...")

        for link in links:
            href = link['href']
            if href.startswith('#') or href.startswith('javascript:'):
                continue
            absolute_url = urljoin(url, href)
            try:
                link_hostname = urlparse(absolute_url).hostname
                if link_hostname and link_hostname.endswith(base_hostname):
                    scraped_data.append([url, absolute_url])
            except ValueError:
                continue

        df = pd.DataFrame(scraped_data, columns=["Halaman Sumber", "Link Keluar (Internal)"])
        print("DataFrame berhasil dibuat.")
        return df 
    
    except requests.exceptions.RequestException as e:
        print(f"Terjadi kesalahan saat mengakses {url}: {e}")
        return pd.DataFrame() # Kembalikan DataFrame kosong jika error

# %%
target_url = "https://its.ac.id"
hasil_df = get_internal_links_df(target_url)
# Out:
# Memeriksa 154 total link yang ditemukan di https://its.ac.id...
# DataFrame berhasil dibuat.

# %%
hasil_df
# Out:
#         Halaman Sumber                             Link Keluar (Internal)
# 0    https://its.ac.id                             https://www.its.ac.id/
# 1    https://its.ac.id                   https://www.its.ac.id/admission/
# 2    https://its.ac.id             https://www.its.ac.id/current-student/
# 3    https://its.ac.id                     https://www.its.ac.id/fresher/
# 4    https://its.ac.id          https://www.its.ac.id/lecturer-and-staff/
# ..                 ...                                                ...
# 119  https://its.ac.id         https://www.its.ac.id/about-its/visit-its/
# 120  https://its.ac.id        https://www.its.ac.id/about-its/its-awards/
# 121  https://its.ac.id               https://www.its.ac.id/?page_id=11494
# 122  https://its.ac.id   https://www.its.ac.id/about-its/executive-board/
# 123  https://its.ac.id  https://www.its.ac.id/about-its/vision-and-mis...
#
# [124 rows x 2 columns]

# %%
hasil_df.to_csv("link_internal_its.csv", index=False)
print("File berhasil disimpan ke link_internal.csv")
# Out:
# File berhasil disimpan ke link_internal.csv
