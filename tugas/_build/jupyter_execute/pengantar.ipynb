# %% [markdown]
# # Pengantar Penambangan Website

# %% [markdown]
# ## 1. Definisi dan Tujuan Web Mining
#
# Web Mining adalah proses penemuan dan ekstraksi informasi yang berguna dari internet melalui berbagai teknik penambangan data. Tujuannya adalah untuk menemukan pola-pola tersembunyi dari struktur hyperlink, konten halaman, dan perilaku pengguna untuk mendukung pengambilan keputusan yang efektif.
#
# Tantangan: Web merupakan sumber data yang sangat besar, kompleks, dinamis, dan tidak spesifik pada satu domain, sehingga memerlukan teknik khusus untuk memprosesnya.
#
# ## 2. Taksonomi Web Mining
#
# Web mining secara umum dibagi menjadi tiga kategori utama:
#
# ### a. Penambangan Konten Web (Web Content Mining)
#
# Fokus pada ekstraksi informasi dari konten halaman web, seperti teks, gambar, audio, dan video.
#
# Aplikasi Utama (Text Mining):
#
# - Klasifikasi Dokumen: Mengkategorikan dokumen ke dalam kelas yang telah ditentukan (misalnya, analisis sentimen, deteksi spam).
#
# - Pengelompokan Dokumen (Clustering): Mengelompokkan dokumen serupa tanpa label kelas sebelumnya (misalnya, pengelompokan hasil pencarian, penemuan topik).
#
# - Ekstraksi Informasi: Mengambil data terstruktur dari teks yang tidak terstruktur (misalnya, mengekstrak nama produk dan harga dari ulasan).
#
# - Analisis Sentimen: Mengklasifikasikan polaritas teks (positif, netral, negatif) untuk memahami opini publik.
#
# ### b. Penambangan Penggunaan Web (Web Usage Mining)
#
# Fokus pada analisis data yang dihasilkan dari interaksi pengguna dengan situs web, seperti clickstream (jejak klik), log server, dan cookie.
#
# Proses: Melibatkan pengumpulan data, pra-pemrosesan, penemuan pola, dan analisis pola.
#
# Aplikasi Utama:
#
# - Rekomendasi Produk: Menyarankan produk kepada pengguna berdasarkan perilaku mereka atau pengguna serupa.
#
# - Pencarian yang Dipersonalisasi: Menyesuaikan hasil pencarian berdasarkan preferensi dan riwayat pengguna.
#
# ### c. Penambangan Struktur Web (Web Structure Mining)
#
# Fokus pada analisis struktur tautan (hyperlink) antar halaman web untuk memahami hubungan dan otoritas.
#
# Konsep Utama:
#
# - Grafik Web (Web Graph): Representasi web di mana halaman adalah simpul (node) dan hyperlink adalah sisi (edge).
#
# - Identifikasi Simpul Penting (Centrality): Menemukan halaman atau pengguna yang paling berpengaruh dalam jaringan (misalnya, algoritma PageRank Google).
#
# - Deteksi Komunitas: Mengidentifikasi kelompok halaman atau pengguna yang saling berinteraksi secara padat.
#
# ## 3. Proses Web Mining
#
# Prosesnya mirip dengan penambangan data pada umumnya, namun dengan penekanan khusus pada tahap pengumpulan dan pra-pemrosesan data web.
#
# - Pengumpulan Data (Gathering): Menggunakan web crawler atau API untuk mengumpulkan dokumen dan data dari web.
#
# - Pra-pemrosesan & Transformasi (Preprocessing & Transformation): Tahap paling memakan waktu (70-80% proyek), mencakup pembersihan data, seleksi fitur, dan transformasi data ke format yang sesuai untuk analisis (misalnya, teks ke vektor).
#
# - Penambangan Data (Actual Data Mining): Menerapkan algoritma penambangan data (klasifikasi, pengelompokan, dll.) untuk menemukan pola.
#
# - Evaluasi & Iterasi: Mengevaluasi model yang dihasilkan dan melakukan eksperimen untuk meningkatkan kualitas dan akurasi.
#
# ## 4. Keterkaitan dengan Bidang Ilmu Lain
#
# Web mining merupakan bidang interdisipliner yang menggabungkan konsep dari:
#
# - Natural Language Processing (NLP)
#
# - Machine Learning
#
# - Database Systems
#
# - Social Network Analysis
#
# - Graph Mining
